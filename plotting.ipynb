# %%
import pickle as pkl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
with open('./Hopper-v2/ARCLSR1500.pkl', 'rb') as file:
    a = pkl.load(file)

with open('./Hopper-v2/trpo500.pkl', 'rb') as file:
    b = pkl.load(file)

# %%
plt.plot(a, label='ARCLSR1')
plt.plot(b, label='trpo')
plt.legend()
plt.show()

# %%
with open('./HalfCheetah-v2/ARCLSR1500.pkl', 'rb') as file:
    a = pkl.load(file)

with open('./HalfCheetah-v2/trpo500.pkl', 'rb') as file:
    b = pkl.load(file)

# %%
plt.plot(a, label='ARCLSR1')
plt.plot(b, label='trpo')
plt.legend()
plt.show()

# %%
with open('./HalfCheetah-v2/ARCLSR1500.pkl', 'rb') as file:
    a = pkl.load(file)

with open('./HalfCheetah-v2/trpo500.pkl', 'rb') as file:
    b = pkl.load(file)

# %%
plt.plot(a, label='ARCLSR1')
plt.plot(b, label='trpo')
plt.legend()
plt.show()

# %%
with open('./Humanoid-v2/ARCLSR1500.pkl', 'rb') as file:
    a = pkl.load(file)

with open('./Humanoid-v2/trpo500.pkl', 'rb') as file:
    b = pkl.load(file)

# %%
plt.plot(a, label='ARCLSR1')
plt.plot(b, label='trpo')
plt.legend()
plt.show()

# %%
with open('./Hopper-v2/ARCLSR1500.pkl', 'rb') as file:
    a = pkl.load(file)

with open('./Hopper-v2/trpo500.pkl', 'rb') as file:
    b = pkl.load(file)

# %%
plt.plot(a, label='ARCLSR1')
plt.plot(b, label='trpo')
plt.legend()
plt.show()
