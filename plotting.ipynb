# %%
import pickle as pkl
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
with open('./Ant-v2/trpo1000.pkl', 'rb') as file:
    a = np.array(pkl.load(file))

with open('./Ant-v2/ARCLSR11000.pkl', 'rb') as file:
    b = np.array(pkl.load(file))

# %%
plt.plot(a[:], label='trpo')
plt.plot(b[:], label='ARCLSR1')
plt.legend()
plt.show()
b =a[:500]
print(b.shape)
print(b[b>3000])
# Out:
# (500,)
# [3003.72796764 3076.62988791 3206.85108069 3011.55975794 3093.69884431
#  3069.81573613 3060.68819195 3174.76796246 3357.66843238 3028.00311589
#  3088.36714751 3001.63142191 3233.69356283 3350.19522001 3138.12979084
#  3252.5275751  3046.68691023 3246.98268488 3178.79305044 3069.46218379
#  3211.62491276 3013.66117547 3193.02869517 3328.03121512 3011.73738508
#  3081.47519882 3329.1682278  3226.48786928 3344.81329578 3415.73819334
#  3177.73709166 3238.92068123 3200.14699169 3180.45180831 3100.25515367
#  3339.20967531 3174.83724095 3401.159235   3206.83025416 3239.7701204
#  3346.04203599 3415.96384057 3645.02343313 3532.5247229  3166.26940732
#  3546.01475847 3219.12071686 3395.15775724 3426.6568131  3426.04293788
#  3438.94343408 3420.76511246 3606.6596003  3556.17073533 3447.6890008
#  3643.31522818 3415.6616042  3291.71061067 3455.77635526 3425.46889682
#  3248.40484217 3527.81233799 3365.41216325 3167.71916495 3587.73936502
# ...

# %%
with open('./Reacher-v2/ARCLSR1500.pkl', 'rb') as file:
    a = pkl.load(file)

with open('./Reacher-v2/trpo500.pkl', 'rb') as file:
    b = pkl.load(file)

# %%
plt.plot(a, label='ARCLSR1')
plt.plot(b, label='trpo')
plt.legend()
plt.show()

# %%
with open('./HalfCheetah-v2/ARCLSR1500-final.pkl', 'rb') as file:
    a = pkl.load(file)

with open('./HalfCheetah-v2/trpo-final.pkl', 'rb') as file:
    b = pkl.load(file)

# %%
plt.plot(a, label='ARCLSR1')
plt.plot(b, label='trpo')
plt.legend()
plt.show()

# %%
with open('./Humanoid-v2/ARCLSR11000.pkl', 'rb') as file:
    a = pkl.load(file)

with open('./Humanoid-v2/trpo1000.pkl', 'rb') as file:
    b = pkl.load(file)

# %%
plt.plot(a[:], label='ARCLSR1')
plt.plot(b[:], label='trpo')
plt.legend()
plt.show()

# %%
index = 257
print(a[index])
print(b[index])
print(max(a))
print(max(b))
# Out:
# 680.8212474275243
# 907.7326124785834
# 2044.9575005650174
# 5827.125679429144

# %%
with open('./Hopper-v2/ARCLSR1500.pkl', 'rb') as file:
    a = pkl.load(file)

with open('./Hopper-v2/trpo500.pkl', 'rb') as file:
    b = pkl.load(file)

# %%
plt.plot(a, label='ARCLSR1')
plt.plot(b, label='trpo')
plt.legend()
plt.show()

# %%
with open('./Walker2d-v2/ARCLSR1500.pkl', 'rb') as file:
    a = pkl.load(file)

with open('./Walker2d-v2/trpo500.pkl', 'rb') as file:
    b = pkl.load(file)

# %%
plt.plot(a[:], label='ARCLSR1')
plt.plot(b[:], label='trpo')
plt.legend()
plt.show()

# %%
with open('./Swimmer-v2/ARCLSR1500.pkl', 'rb') as file:
    a = pkl.load(file)

with open('./Swimmer-v2/trpo500.pkl', 'rb') as file:
    b = pkl.load(file)

# %%
plt.plot(a[:], label='ARCLSR1')
plt.plot(b[:], label='trpo')
plt.legend()
plt.show()

# %%
with open('./InvertedDoublePendulum-v2/ARCLSR1500.pkl', 'rb') as file:
    a = pkl.load(file)

with open('./InvertedDoublePendulum-v2/trpo500.pkl', 'rb') as file:
    b = pkl.load(file)

# %%
plt.plot(a[:], label='ARCLSR1')
plt.plot(b[:], label='trpo')
plt.legend()
plt.show()

# %%
with open('./InvertedPendulum-v2/ARCLSR1500.pkl', 'rb') as file:
    a = pkl.load(file)

with open('./InvertedPendulum-v2/trpo500.pkl', 'rb') as file:
    b = pkl.load(file)

# %%
plt.plot(a[:], label='ARCLSR1')
plt.plot(b[:], label='trpo')
plt.legend()
plt.show()

# %%
with open('./HumanoidStandup-v2/ARCLSR1500.pkl', 'rb') as file:
    a = pkl.load(file)

with open('./HumanoidStandup-v2/trpo500.pkl', 'rb') as file:
    b = pkl.load(file)

# %%
plt.plot(a[:], label='ARCLSR1')
plt.plot(b[:], label='trpo')
plt.legend()
plt.show()
