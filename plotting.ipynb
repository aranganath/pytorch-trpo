# %%
import pickle as pkl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
with open('./Reacher-v2/ARCLSR1.pkl', 'rb') as file:
    a = pkl.load(file)

with open('./Reacher-v2/TRPO.pkl', 'rb') as file:
    b = pkl.load(file)

# %%
plt.plot(a, label='ARCLSR1')
plt.plot(b, label='trpo')
plt.legend()
plt.show()

# %%
with open('./Ant-v2/ARCLSR1_final.pkl', 'rb') as file:
    a = pkl.load(file)

with open('./Ant-v2/TRPO.pkl', 'rb') as file:
    b = pkl.load(file)

# %%
plt.plot(a, label='ARCLSR1')
plt.plot(b, label='trpo')
plt.legend()
plt.show()

# %%
with open('./Humanoid-v2/ARCLSR1.pkl', 'rb') as file:
    a = pkl.load(file)

with open('./Humanoid-v2/TRPO.pkl', 'rb') as file:
    b = pkl.load(file)

# %%
plt.plot(a, label='ARCLSR1')
plt.plot(b, label='trpo')
plt.legend()
plt.show()

# %%
with open('./Hopper-v2/ARCLSR1.pkl', 'rb') as file:
    a = pkl.load(file)

with open('./Hopper-v2/TRPO.pkl', 'rb') as file:
    b = pkl.load(file)

# %%
plt.plot(a, label='ARCLSR1')
plt.plot(b, label='trpo')
plt.legend()
plt.show()

# %%
with open('./HalfCheetah-v2/ARCLSR1.pkl', 'rb') as file:
    a = pkl.load(file)

with open('./HalfCheetah-v2/TRPO.pkl', 'rb') as file:
    b = pkl.load(file)

# %%
plt.plot(a, label='ARCLSR1')
plt.plot(b, label='trpo')
plt.legend()
plt.show()
